# %%
import pandas as pd
df = pd.read_csv("Inventory Items.csv")

# %%
# STEP 3: Define Category Mappings
category_keywords = {
    "meals": [
        "meal", "dinner", "soup", "turkey", "hot", "chili", "plate", "prepared", "sandwich", "kitchen",
        "quiche", "pot pie", "ham", "steak", "drumstick", "sausage", "frozen"
    ],
    "pantry": [
        "canned", "beans", "rice", "grain", "vegetable", "fruit", "donation", "non-perishable", "dry goods",
        "tuna", "apple", "pepper", "pasta", "sauce", "v8", "bloody mary", "dessert",
        "yogurt", "eggs", "juice", "milk", "nuts", "snack", "granola", "protein", 
        "gatorade", "soda", "pretzels", "cookie", "chips", "butter", "cheese",
        "cereal", "cracker", "bar", "popcorn", "drink", "beverage", "oats",
        "onion", "potato", "ginger", "bread", "bun", "coffee", "creamer", "half and half", "tea"
    ],
    "hygiene": [
        "soap", "toothbrush", "shampoo", "kit", "sanitary", "deodorant", "toothpaste", "body wash", "basic needs",
        "bathroom", "toilet", "hand sanitizer", "razor", "q-tip", "lip balm", "conditioner", "paper towel", "napkin"
    ],
    "clothing": [
        "shirt", "jacket", "sock", "pants", "coat", "clothing", "sweater", "blanket"
    ],
    "medical": [
        "syringe", "naloxone", "first aid", "bandage", "gloves", "test kit",
        "ssdi", "ssi", "snap", "medicare", "medicaid", "husky", "insurance", "medical assistance"
    ],
    "case_management": [
        "vital document", "section 8", "dmv", "id", "birth certificate", "social security", "homeless",
        "housing support", "phone", "assurance", "safelink", "spdat", "verification", "benefit enrollment"
    ],
    "harm_reduction": [
        "meth", "prep pad", "ziplock", "pipe", "straw", "foil", "chore boy", "lube", "screen", "razor blade",
        "teaspoon", "mouth piece", "q-tip", "chopstick", "cotton balls", "vitamin c powder"
    ],
    "pet_care": [
        "dog food", "cat food", "pet"
    ],
    "donated_goods": [  # New for things like toys, stuffed animals, etc.
        "toy", "stuffed animal", "non-food", "miscellaneous"
    ]
}

# STEP 4: Define Category-to-Code Mapping
category_code_map = {
    "meals":     ("020", "1"),
    "pantry":    ("030", "4"),
    "hygiene":   ("040", "2"),
    "clothing":  ("010", "6"),
    "medical":   ("040", "5"),
    "case_management": ("050", "7")
}

# Add new category mappings
category_code_map.update({
    "harm_reduction": ("040", "9"),
    "pet_care": ("060", "8"),
    "donated_goods": ("070", "3")
})

# STEP 5: Program and Building Maps
program_map = {
    "drop in": "1",
    "outreach": "2",
    "pantry": "3"
}

building_map = {
    "266": "266",  # Main
    "260": "260",  # Storage
    "151": "151"   # Admin
}

# %%
# STEP 6: Item Number Generation Logic
# =======================
def generate_category_based_item_number(row):
    name = str(row.get('Name', '')).lower()
    type_ = str(row.get('Type', '')).lower()
    tags = str(row.get('Tags', '')).lower()
    number = str(row.get('Number', '')).lower()

    # Category → Department + ItemType
    dept_code = "000"
    item_type_code = "0"
    for cat, keywords in category_keywords.items():
        if any(kw in name or kw in type_ or kw in tags for kw in keywords):
            dept_code, item_type_code = category_code_map.get(cat, ("000", "0"))
            break

    # Program
    prog_code = "0"
    for keyword, code in program_map.items():
        if keyword in name or keyword in tags:
            prog_code = code
            break

    # Building
    bldg_code = "000"
    for bcode in building_map:
        if number.startswith(bcode) or bcode in tags:
            bldg_code = building_map[bcode]
            break

    return f"{dept_code}{prog_code}.{item_type_code}-{bldg_code}"

# %%
# )=====================================
# STEP 5: Apply to your DataFrame
# =====================================
df['FormattedItemNumber'] = df.apply(generate_category_based_item_number, axis=1)

# %%
# =====================================
# STEP 6: Save to Excel for future edits
# =====================================
df.to_excel("cleaning_workbook.xlsx", index=False)

# %%
df
# Out:
#        Number               Type                                      Name  \
# 0       266-1       DESK Dinners                      Servery at 266 State
# 1       266-2       DESK Dinners                       DESK Outreach Meals
# 2       266-3       DESK Dinners          Chapel on the Green Meal Service
# 3       266-4       DESK Dinners  Trinity Church on the Green Meal Service
# 4       266-5       DESK Dinners              New Haven Green Meal Service
# ..        ...                ...                                       ...
# 969  33020252      Ready to Bake                      Beans Northern Dried
# 970  33020253      Ready to Bake            Sea Salt Caramel Dessert Sauce
# 971  33020254      Ready to Bake                            V8 Bloody Mary
# 972  33020255      Ready to Bake                               Pasta Elbow
# 973      4645  Basic Needs Items                        Basic Needs - Tarp
#
#     Override Rules  Unit  Value/ Unit  Weight/ Unit  \
# 0              NaN   Bag          0.0           0.0
# 1              NaN   Bag          0.0           0.0
# 2              NaN  Each          0.0           0.0
# 3              NaN  Each          0.0           0.0
# 4              NaN  Each          0.0           0.0
# ..             ...   ...          ...           ...
# 969            NaN   Bag          0.0           0.0
# 970            NaN   Bag          0.0           0.0
# 971            NaN   Bag          0.0           0.0
# 972            NaN   Bag          0.0           0.0
# 973            NaN  Each          0.0           0.0
#
#                                                   Tags  \
# 0                                 266 - Meals, Current
# 1                                                MEALS
# 2                                                MEALS
# 3                                                MEALS
# 4                                                MEALS
# ..                                                 ...
# 969                                                NaN
# 970                                                NaN
# 971                                                NaN
# 972                                                NaN
# 973  Harm Reduction, Personal Care Item, Street Bag...
#
#                                     Groups  Status            Shows On  \
# 0                                      NaN  Active        Visit,Kiosk,
# 1                                      NaN  Active              Visit,
# 2                                      NaN  Active  Visit,Kiosk,Store,
# 3                                      NaN  Active  Visit,Kiosk,Store,
# 4                                      NaN  Active  Visit,Kiosk,Store,
# ..                                     ...     ...                 ...
# 969              Beans Northern Dried Case  Active  Visit,Kiosk,Store,
# 970   Sea Salt Caramel Dessert Sauce  Case  Active  Visit,Kiosk,Store,
# 971                    V8 Bloody Mary Case  Active  Visit,Kiosk,Store,
# 972                       Pasta Elbow Case  Active  Visit,Kiosk,Store,
# 973                                    NaN  Active              Visit,
#
#     FormattedItemNumber
# 0            0200.1-266
# 1            0202.1-266
# 2            0200.1-266
# 3            0200.1-266
# 4            0200.1-266
# ..                  ...
# 969          0300.4-000
# 970          0300.4-000
# 971          0300.4-000
# 972          0300.4-000
# 973          0400.2-000
#
# [974 rows x 12 columns]

# %%
unmatched = df[df['FormattedItemNumber'].str.startswith("0000")]
print(f"\n❗ Unmatched items (start with '0000'): {len(unmatched)}")
print(unmatched[['Name', 'Type', 'Number', 'FormattedItemNumber']].head(100))
# Out:
# ❗ Unmatched items (start with '0000'): 47
#                                                  Name  \
# 152                                              Bags
# 155                                       Paper Goods
# 163                                             Candy
# 174                          Tender Mercies - Regular
# 176                        Half & Half - Shelf Stable
# 184                                Grocery - Assorted
# 213                                 Water - Sparkling
# 215                                 Water - Sparkling
# 228                                Grocery - Assorted
# 233                                           Noodles
# 245                                              Baby
# 247                                              Bags
# 250                                       Paper Goods
# 256                        Half & Half - Shelf Stable
# 258                          Tender Mercies - Regular
# 268                                         Pop Tarts
# 271                                          Cheez It
# 310                              Chicken Breast Filet
# 339                                  Chicken ala king
# 405                                     Powerade Zero
# 406                                      Pringles Can
# 409                          Cup o Noodles - Assorted
# 414                              Smart Water - Bottle
# 433         Harm Reduction Components - Sterile Water
# 435             Harm Reduction Components - Rinse Cap
# 439            Harm Reduction Components - Pyrex Stem
# 442            Harm Reduction Components - Paper Clip
# 445     Harm Reduction Components - Hard Candy / Mint
# 480                            Shredded Chicken Pouch
# 555  Harm Reduction Components - Amber Light-lock Bag
# 557       Harm Reduction Components - CPR Face Shield
# 609                                          Porkchop
# 720                                  Balsamic Vinegar
# 732                                 Grape Jelly 3,7kg
# 739                              Carne Asada Marinade
# 741                              Meyer Lemon Marinade
# 804                                Dill Pickle Relish
# 805                                     Dijon Mustard
# 809                         Yellow Mustard Jars (3kg)
# 908                           Meat Processed Uncooked
# 914                       Chicken 8 Piece Cut 1/50lbs
# 938                                         Oikos Pro
# 940                               Naked Green Machine
# 941                                      Chabani Flip
# 943                                     Chobani Greek
# 967                                Peaches Fresh Case
# 968                                        Water Case
#
#                           Type         Number FormattedItemNumber
# 152  Drop-in & Resource Center        8079994          0000.0-000
# 155  Drop-in & Resource Center        8079997          0000.0-000
# 163  Drop-in & Resource Center        8080005          0000.0-000
# 174  Drop-in & Resource Center        8080016          0000.0-000
# 176  Drop-in & Resource Center        8080018          0000.0-000
# 184  Drop-in & Resource Center        8080026          0000.0-000
# 213  Drop-in & Resource Center        8303888          0000.0-000
# 215  Drop-in & Resource Center        8303890          0000.0-000
# 228  Drop-in & Resource Center        8303903          0000.0-000
# 233  Drop-in & Resource Center        8303908          0000.0-000
# 245  Drop-in & Resource Center        8303920          0000.0-000
# 247  Drop-in & Resource Center        8303922          0000.0-000
# 250  Drop-in & Resource Center        8303925          0000.0-000
# 256  Drop-in & Resource Center        8303931          0000.0-000
# 258  Drop-in & Resource Center        8303933          0000.0-000
# 268  Drop-in & Resource Center        8303943          0000.0-000
# 271  Drop-in & Resource Center        8303946          0000.0-000
# 310                       Meat        8303959          0000.0-000
# 339                       Meat  DSKNVCHIKIN10          0000.0-000
# 405            Non-Visit Items        8303965          0000.0-000
# 406            Non-Visit Items        8303966          0000.0-000
# 409            Non-Visit Items        8303969          0000.0-000
# 414  Drop-in & Resource Center        8303974          0000.0-000
# 433  Drop-in & Resource Center        HR-0002          0000.0-000
# 435  Drop-in & Resource Center        HR-0004          0000.0-000
# 439  Drop-in & Resource Center        HR-0008          0000.0-000
# 442  Drop-in & Resource Center        HR-0011          0000.0-000
# 445  Drop-in & Resource Center        HR-0014          0000.0-000
# 480                       Meat        8304004          0000.0-000
# 555  Drop-in & Resource Center        8304079          0000.0-000
# 557  Drop-in & Resource Center        8304081          0000.0-000
# 609                       Meat        8304111          0000.0-000
# 720                Jarred Item    8.30419E+17          0000.0-000
# 732                Jarred Item    1.844674407          0000.0-000
# 739                Jarred Item    1.84467E+12          0000.0-000
# 741                Jarred Item    1.84467E+12          0000.0-000
# 804                Jarred Item    1.844674407          0000.0-000
# 805                Jarred Item    1.844674407          0000.0-000
# 809                Jarred Item    1.844674407          0000.0-000
# 908                       Meat        8150023          0000.0-000
# 914                       Meat         700739          0000.0-000
# 938                      Dairy     3663204269          0000.0-000
# 940                      Dairy    82592720153          0000.0-000
# 941                      Dairy     8.1829E+11          0000.0-000
# 943                      Dairy      8.947E+11          0000.0-000
# 967              Ready to Bake       33020250          0000.0-000
# 968              Ready to Bake       33020251          0000.0-000

# %%
unmatched.to_excel(r"E:\pantry\needs_manual_review.xlsx", index=False)
print("📄 Saved: needs_manual_review.xlsx")
# Out:
# 📄 Saved: needs_manual_review.xlsx
